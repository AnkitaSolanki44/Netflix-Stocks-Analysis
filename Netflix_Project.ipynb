# %% [markdown]
# # NETFLIX STOCK ANALYSIS PROJECT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
df=pd.read_csv(r'C:\Users\Jaimin Solanki\Downloads\netflix_sample_data.txt')

# %%
df
# Out:
#           Date     Open     High      Low    Close  Adj Close   Volume
# 0   2025-06-18  1229.99  1242.00  1220.50  1222.29    1222.29  2267450
# 1   2025-06-17  1219.95  1232.36  1216.09  1220.67    1220.67  1892126
# 2   2025-06-16  1212.20  1226.25  1212.20  1225.35    1225.35  2112797
# 3   2025-06-13  1206.59  1220.62  1201.89  1212.15    1212.15  2210253
# 4   2025-06-12  1222.59  1230.00  1211.97  1215.03    1215.03  2084602
# 5   2025-06-11  1202.60  1228.29  1196.01  1219.88    1219.88  2382280
# 6   2025-06-10  1227.52  1227.52  1180.61  1203.62    1203.62  4454447
# 7   2025-06-09  1238.88  1238.88  1221.57  1224.46    1224.46  2403117
# 8   2025-06-06  1259.41  1260.00  1235.55  1241.48    1241.48  2556956
# 9   2025-06-05  1240.60  1262.81  1237.29  1250.52    1250.52  2821797
# 10  2025-06-04  1245.00  1258.00  1235.00  1248.00    1248.00  2760000
# 11  2025-06-03  1235.00  1255.00  1225.00  1240.00    1240.00  2630000
# 12  2025-06-02  1220.00  1240.00  1210.00  1225.00    1225.00  2500000
# 13  2025-05-30  1200.00  1225.00  1195.00  1210.00    1210.00  2400000
# 14  2025-05-29  1185.00  1210.00  1175.00  1200.00    1200.00  2300000

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close   Volume
# 0  2025-06-18  1229.99  1242.00  1220.50  1222.29    1222.29  2267450
# 1  2025-06-17  1219.95  1232.36  1216.09  1220.67    1220.67  1892126
# 2  2025-06-16  1212.20  1226.25  1212.20  1225.35    1225.35  2112797
# 3  2025-06-13  1206.59  1220.62  1201.89  1212.15    1212.15  2210253
# 4  2025-06-12  1222.59  1230.00  1211.97  1215.03    1215.03  2084602

# %%
sns.set(rc={'figure.figsize':(10,5)})

# %%
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')
df.head()
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2025-06-18  1229.99  1242.00  1220.50  1222.29    1222.29  2267450
# 2025-06-17  1219.95  1232.36  1216.09  1220.67    1220.67  1892126
# 2025-06-16  1212.20  1226.25  1212.20  1225.35    1225.35  2112797
# 2025-06-13  1206.59  1220.62  1201.89  1212.15    1212.15  2210253
# 2025-06-12  1222.59  1230.00  1211.97  1215.03    1215.03  2084602

# %%
sns.lineplot(x=df.index,y=df['Volume'],label='volume')
plt.title('volume versus time')
# Out:
# Text(0.5, 1.0, 'volume versus time')

# %%
df.plot(y=['High','Close','Open'],title='Netflix Stock Price')
# Out:
# <Axes: title={'center': 'Netflix Stock Price'}>

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,figsize=(15,10))
df.groupby(df.index.day).mean().plot(y='Volume',ax=ax1,xlabel='Day')
df.groupby(df.index.month).mean().plot(y='Volume',ax=ax2,xlabel='Month')
df.groupby(df.index.year).mean().plot(y='Volume',ax=ax3,xlabel='Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Dates with Highest Stock Price

# %%
df
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2025-06-18  1229.99  1242.00  1220.50  1222.29    1222.29  2267450
# 2025-06-17  1219.95  1232.36  1216.09  1220.67    1220.67  1892126
# 2025-06-16  1212.20  1226.25  1212.20  1225.35    1225.35  2112797
# 2025-06-13  1206.59  1220.62  1201.89  1212.15    1212.15  2210253
# 2025-06-12  1222.59  1230.00  1211.97  1215.03    1215.03  2084602
# 2025-06-11  1202.60  1228.29  1196.01  1219.88    1219.88  2382280
# 2025-06-10  1227.52  1227.52  1180.61  1203.62    1203.62  4454447
# 2025-06-09  1238.88  1238.88  1221.57  1224.46    1224.46  2403117
# 2025-06-06  1259.41  1260.00  1235.55  1241.48    1241.48  2556956
# 2025-06-05  1240.60  1262.81  1237.29  1250.52    1250.52  2821797
# 2025-06-04  1245.00  1258.00  1235.00  1248.00    1248.00  2760000
# 2025-06-03  1235.00  1255.00  1225.00  1240.00    1240.00  2630000
# 2025-06-02  1220.00  1240.00  1210.00  1225.00    1225.00  2500000
# 2025-05-30  1200.00  1225.00  1195.00  1210.00    1210.00  2400000
# 2025-05-29  1185.00  1210.00  1175.00  1200.00    1200.00  2300000

# %%
a=df.sort_values(by='High',ascending=False).head(5)
a['High']
# Out:
# Date
# 2025-06-05    1262.81
# 2025-06-06    1260.00
# 2025-06-04    1258.00
# 2025-06-03    1255.00
# 2025-06-18    1242.00
# Name: High, dtype: float64

# %%
b=df.sort_values(by='Low',ascending=True).head(5)
b['Low']
# Out:
# Date
# 2025-05-29    1175.00
# 2025-06-10    1180.61
# 2025-05-30    1195.00
# 2025-06-11    1196.01
# 2025-06-13    1201.89
# Name: Low, dtype: float64

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,sharex=True,figsize=(12,5))
fig.suptitle('High & Low values Stock per period of time',fontsize=18)
sns.lineplot(ax=axes[0],y=df['High'],x=df.index,color='green')
sns.lineplot(ax=axes[1],y=df['Low'],x=df.index,color='blue')
# Out:
# <Axes: xlabel='None', ylabel='Low'>

# %%
# 🔹  Plot Closing Price Over Time

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'],label='Closing Price')
plt.title('Netflix Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price(USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 🔹  Calculate Daily Returns

# %%
df['Daily Return']=df['Close'].pct_change()
df['Daily Return'].plot(figsize=(12,6),title='Daily Returns')
# Out:
# <Axes: title={'center': 'Daily Returns'}>
